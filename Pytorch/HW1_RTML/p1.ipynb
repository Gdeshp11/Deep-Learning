# %%
import torch

from torchvision import transforms

from PIL import Image

img = Image.open("images/blue3.jpg")
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2000x1000 at 0x7FBA742C3BB0>

# %%
# convert image to tensor
convert_tensor = transforms.ToTensor()
img_tensor = convert_tensor(img)
img_tensor[1:2]
# Out:
# tensor([[[0.3804, 0.3804, 0.3804,  ..., 0.3804, 0.3804, 0.3804],
#          [0.3804, 0.3804, 0.3804,  ..., 0.3804, 0.3804, 0.3804],
#          [0.3804, 0.3804, 0.3804,  ..., 0.3804, 0.3804, 0.3804],
#          ...,
#          [0.3804, 0.3804, 0.3804,  ..., 0.3804, 0.3804, 0.3804],
#          [0.3804, 0.3804, 0.3804,  ..., 0.3804, 0.3804, 0.3804],
#          [0.3804, 0.3804, 0.3804,  ..., 0.3804, 0.3804, 0.3804]]])

# %%
# get mean of image tensor
mean = torch.mean(img_tensor)
mean
# Out:
# tensor(0.3412)

# %%
# Compute mean of each channel in image
Red_mean, Green_mean ,Blue_mean = torch.mean(img_tensor, dim = [1,2])

# print mean across image channel RGB
print("Red channel mean:", Red_mean)
print("Green channel mean:", Green_mean)
print("Blue channel mean:", Blue_mean)
# Out:
# Red channel mean: tensor(0.0275)
# Green channel mean: tensor(0.3804)
# Blue channel mean: tensor(0.6157)
